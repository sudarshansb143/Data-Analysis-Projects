# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as ws
ws.filterwarnings("ignore")

# %%
df  = pd.read_csv("/kaggle/input/best-buy-indian-bikes/Bikes Best Buy.csv")

# %%
df.head()
# Out:
#           Bike Name  Milage (kM/L)  Tank size (cc)   Price(INR) Fuel  Company
# 0     Royal Enfield             50              500      350000    D   Bullet
# 1           Rajdoot             60              500       50000    D  Rajdoot
# 2     Splender Plus             65              100       65000    P     Hero
# 3  Splender Pro NXG             61              120       66003    P     Hero
# 4    Super Splender             60              125       66200    P     Hero

# %%
# Cleaning the names of the columns
def clean_name(name):
    return name.strip().lower().replace(" ", "_")

df.rename(columns = clean_name, inplace = True)

# %%
sns.set()
#Checking the Fuel type of bike 
sns.countplot(df["fuel"])
plt.show()

# %%
#Signifying the companies who manifatured the bikes
temp = df.company.value_counts().reset_index()

# %%
sns.barplot(y="index", x="company" , data =temp)
plt.show()

# %%
df.bike_name.unique().shape
# Out:
# (60,)

# %%
df.describe()
# Out:
#        milage_(km/l)  tank_size_(cc)     price(inr)
# count      60.000000       60.000000      60.000000
# mean       60.716667      362.666667  166511.650000
# std        15.388849      439.492453  190156.497187
# min        20.000000        0.000000   45000.000000
# 25%        50.000000      120.000000   67875.000000
# 50%        60.000000      172.500000   82500.000000
# 75%        70.000000      363.000000  140250.000000
# max        95.000000     1868.000000  972220.000000

# %%
# Viewing the distribution of the numeric coulumn
num_col = ['milage_(km/l)',
 'tank_size_(cc)',
 'price(inr)']
for i in num_col:
    sns.distplot(df[i])
    plt.show()

# %%
avg_per_catagaory_of_fuel =  df.groupby("fuel")["milage_(km/l)"].mean().reset_index()

# %%
avg_per_catagaory_of_fuel
# Out:
#   fuel  milage_(km/l)
# 0    D      49.800000
# 1    E      70.000000
# 2    P      61.396226

# %% [markdown]
# **Upvote it if you find it useful ****
